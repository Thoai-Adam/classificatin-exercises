# %%
# %autosave 0
# Out:
# Autosave disabled

# %% [markdown]
# # Data Acquitision Exercises

# %%
#importing everything, sending everyone
import pandas as pd
import numpy as np
import os

#acquire
from env import get_connection
from pydataset import data
import seaborn as sns

# %% [markdown]
# ### 4.Use pydata or seaborn containing datasets as source for iris data. create pandas dataframe, df_iris, from this data
#    #### a. print the first 3 rows
#    #### b. print the number of rows and columns (shape)
#    #### c. print the column names
#    #### d. print the data type of each column
#    #### e. print the summary statistics for each of the numeric variable

# %%
# load iris data set 
df_iris =  data('iris')
df_iris.head(3)
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 1           5.1          3.5           1.4          0.2  setosa
# 2           4.9          3.0           1.4          0.2  setosa
# 3           4.7          3.2           1.3          0.2  setosa

# %%
df_iris.shape
# Out:
# (150, 5)

# %%
df_iris.columns
# Out:
# Index(['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width',
#        'Species'],
#       dtype='object')

# %%
#return only data types
df_iris.dtypes
#return columns and data types
df_iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150 entries, 1 to 150
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal.Length  150 non-null    float64
#  1   Sepal.Width   150 non-null    float64
#  2   Petal.Length  150 non-null    float64
#  3   Petal.Width   150 non-null    float64
#  4   Species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 7.0+ KB

# %%
df_iris.describe()
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
#summary statistic for each numeric variable
#the .T function will transpose the DF to make it more readable
stats = df_iris.describe().T
stats
# Out:
#               count      mean       std  min  25%   50%  75%  max
# Sepal.Length  150.0  5.843333  0.828066  4.3  5.1  5.80  6.4  7.9
# Sepal.Width   150.0  3.057333  0.435866  2.0  2.8  3.00  3.3  4.4
# Petal.Length  150.0  3.758000  1.765298  1.0  1.6  4.35  5.1  6.9
# Petal.Width   150.0  1.199333  0.762238  0.1  0.3  1.30  1.8  2.5

# %% [markdown]
# ### Read the data from a Google sheet into a dataframe, df_google
#  #### a. print the first 3 rows
#  #### b. print the number of rows and columns
#  #### c. print the column names
#  #### d. print the data type of each column
#  #### e. print the summary statistics for each of the numeric variables
#  #### f. print the unique values for each of your categorical variables

# %%
#grab the google sheet url 
sheet_url = 'https://docs.google.com/spreadsheets/d/1Uhtml8KY19LILuZsrDtlsHHDC9wuDGUSe8LTEwvdI5g/edit#gid=341089357'

# %%
#turn Google sheet address into CSV export URL
csv_export_url = sheet_url.replace('/edit#gid=', '/export?format=csv&gid=')

# %%
# Read in the data using the pandas pd.read_csv() function
df_google = pd.read_csv(csv_export_url)

# %%
df_google.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df_google.shape
# Out:
# (891, 12)

# %%
df_google.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df_google.describe().T
# Out:
#              count        mean         std   min       25%       50%    75%  \
# PassengerId  891.0  446.000000  257.353842  1.00  223.5000  446.0000  668.5
# Survived     891.0    0.383838    0.486592  0.00    0.0000    0.0000    1.0
# Pclass       891.0    2.308642    0.836071  1.00    2.0000    3.0000    3.0
# Age          714.0   29.699118   14.526497  0.42   20.1250   28.0000   38.0
# SibSp        891.0    0.523008    1.102743  0.00    0.0000    0.0000    1.0
# Parch        891.0    0.381594    0.806057  0.00    0.0000    0.0000    0.0
# Fare         891.0   32.204208   49.693429  0.00    7.9104   14.4542   31.0
#
#                   max
# PassengerId  891.0000
# Survived       1.0000
# Pclass         3.0000
# Age           80.0000
# SibSp          8.0000
# Parch          6.0000
# Fare         512.3292

# %%
df_google.columns.to_list()  
#by commanding to_list() i can make the list horizontal
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
#call on data type
df_google.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df_google.describe().T

###note to self, ask Adam how to turn all these annoying numbers
###into to decimal places
# Out:
#              count        mean         std   min       25%       50%    75%  \
# PassengerId  891.0  446.000000  257.353842  1.00  223.5000  446.0000  668.5
# Survived     891.0    0.383838    0.486592  0.00    0.0000    0.0000    1.0
# Pclass       891.0    2.308642    0.836071  1.00    2.0000    3.0000    3.0
# Age          714.0   29.699118   14.526497  0.42   20.1250   28.0000   38.0
# SibSp        891.0    0.523008    1.102743  0.00    0.0000    0.0000    1.0
# Parch        891.0    0.381594    0.806057  0.00    0.0000    0.0000    0.0
# Fare         891.0   32.204208   49.693429  0.00    7.9104   14.4542   31.0
#
#                   max
# PassengerId  891.0000
# Survived       1.0000
# Pclass         3.0000
# Age           80.0000
# SibSp          8.0000
# Parch          6.0000
# Fare         512.3292

# %%
#the assignment is to print the unique values for each categorical variables
#these categorical variable columns have a lot of unique values

for col in df_google.columns:
    if df_google[col].dtypes == 'object':
        print(f'{col} has {df_google[col].nunique()} unique values.')
# Out:
# Name has 891 unique values.
# Sex has 2 unique values.
# Ticket has 681 unique values.
# Cabin has 147 unique values.
# Embarked has 3 unique values.

# %%
df_google.Survived.value_counts(dropna = False)
#why doesn't the survive work?

#by default missing values are excluded in the count
#the dropna = False parameter will include all value counts
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df_google.Pclass.value_counts(dropna=False)
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df_google.Sex.value_counts(dropna = False)
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df_google.Embarked.value_counts(dropna=False)
# Out:
# S      644
# C      168
# Q       77
# NaN      2
# Name: Embarked, dtype: int64

# %% [markdown]
# ## 6. Download the previous exercise' file into an excel (File -> Download -> Microsoft Excel). Read the downloaded file into a dataframe named df_excel
#
#
# #### a. assign the first 100 rows to a new dataframe, df_excel_sample
# #### b. print the number of rows of your original dataframe
# #### c. print hte first 5 column names
# #### d. print the column names that have a data type of object
# #### e. compute the range for each of the numeric variables

# %%
df_excel = pd.read_excel('train.xlsx', sheet_name = 'train')

# %%
df_excel_sample = df_excel.head(100)

# %%
df_excel_sample.shape
# Out:
# (100, 12)

# %%
df_excel.shape[0]
# Out:
# 891

# %%
df_excel.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df_excel.columns[:5]
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex'], dtype='object')

# %%
df_excel.columns[5:]  
#why did this command show last 7 instead of last 5
# Out:
# Index(['Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'], dtype='object')

# %%
#column name of object type
df_excel.select_dtypes(include = 'object')
# Out:
#                                                     Name     Sex  \
# 0                                Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female
# 2                                 Heikkinen, Miss. Laina  female
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                               Allen, Mr. William Henry    male
# ..                                                   ...     ...
# 886                                Montvila, Rev. Juozas    male
# 887                         Graham, Miss. Margaret Edith  female
# 888             Johnston, Miss. Catherine Helen "Carrie"  female
# 889                                Behr, Mr. Karl Howell    male
# 890                                  Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# ...

# %%
df_excel.select_dtypes(include = 'object').head(0)
#including the .head(0) will only give you the title row
# Out:
# Empty DataFrame
# Columns: [Name, Sex, Ticket, Cabin, Embarked]
# Index: []

# %%
df_excel.select_dtypes(include='object').columns.to_list()
#columns.to_list() command turn those column into a list
# Out:
# ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked']

# %%
df_excel.head() 
#from here i can see Pclass, age, SibSp, Survived, and Fare are numeric variables
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
#Instruction were to get the range of age and fare
df_excel[['Age', 'Fare']]
#If you were to use single bracket , pandas will treat it
#as a list of column names and try to select subset of column as Series
#you want a new dataframe containing multiple specific columns
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %% [markdown]
# ### The double bracket tell Pandas you need to create a nested list of specific column to create a DataFrame
#
# ### The steps to find range, is to Tranpose the described specified columns, then to put the range equation in a range variable

# %%
titanic_stats = df_excel[['Age','Fare']].describe().T
titanic_stats
# Out:
#       count       mean        std   min      25%      50%   75%       max
# Age   714.0  29.699118  14.526497  0.42  20.1250  28.0000  38.0   80.0000
# Fare  891.0  32.204208  49.693429  0.00   7.9104  14.4542  31.0  512.3292

# %%
#Range of the two column. 
titanic_stats['range'] = titanic_stats['max'] - titanic_stats['min']
titanic_stats
# Out:
#       count       mean        std   min      25%      50%   75%       max  \
# Age   714.0  29.699118  14.526497  0.42  20.1250  28.0000  38.0   80.0000
# Fare  891.0  32.204208  49.693429  0.00   7.9104  14.4542  31.0  512.3292
#
#          range
# Age    79.5800
# Fare  512.3292

# %% [markdown]
# # Data Preparation Exercises
#
# Use the function defined in acquire.py to load the iris data.
# Drop the species_id and measurement_id columns.
# Rename the species_name column to just species.
# Create dummy variables of the species name and concatenate onto the iris dataframe. (This is for practice, we don't always have to encode the target, but if we used species as a feature, we would need to encode it).
# Create a function named prep_iris that accepts the untransformed iris data, and returns the data with the transformations above applied.

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
from env import get_connection
from pydataset import data
from sqlalchemy import create_engine, text
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
import os

import numpy as np
import pandas as pd

from env import get_connection

def get_db_connection(database):
    return get_connection(database)

# %%
def new_iris_data():
    sql_query = ("SELECT species_id, species_name, sepal_length, sepal_width, petal_length, petal_width FROM measurements JOIN species USING(species_id)")
    # Read in datafr from Codeup db.
    df = pd.read_sql(sql_query, get_connection('iris_db'))
    return df


def get_iris_data():
    if os.path.isfile('iris_df.csv'):
        # If csv file exists read in data from csv file.
        df = pd.read_csv('iris_df.csv', index_col=0)
    else:   
        # Read fresh data from Codeup db into a dataframe
        df = new_iris_data() 
        # Cache data
        df.to_csv('iris_df.csv')
    return df

# %%
# from acquire import new_iris_data  
#this command was not needed since I have defined new_iris_data above
#as well as specify where to read the information

# %%
df_iris = new_iris_data()
df_iris.head()
# Out:
#    species_id species_name  sepal_length  sepal_width  petal_length  \
# 0           1       setosa           5.1          3.5           1.4
# 1           1       setosa           4.9          3.0           1.4
# 2           1       setosa           4.7          3.2           1.3
# 3           1       setosa           4.6          3.1           1.5
# 4           1       setosa           5.0          3.6           1.4
#
#    petal_width
# 0          0.2
# 1          0.2
# 2          0.2
# 3          0.2
# 4          0.2

# %%
new_df_iris = df_iris.drop(columns=['species_id'])
#for some reason, measurement_id was not found in the intial axis
#this define the new dataframe for iris without the two columns
new_df_iris.head()
# Out:
#   species_name  sepal_length  sepal_width  petal_length  petal_width
# 0       setosa           5.1          3.5           1.4          0.2
# 1       setosa           4.9          3.0           1.4          0.2
# 2       setosa           4.7          3.2           1.3          0.2
# 3       setosa           4.6          3.1           1.5          0.2
# 4       setosa           5.0          3.6           1.4          0.2

# %%
new_df_iris = new_df_iris.rename(columns = {'species_name' : 'species'})
new_df_iris.head()
# the name has been changed
# Out:
#   species  sepal_length  sepal_width  petal_length  petal_width
# 0  setosa           5.1          3.5           1.4          0.2
# 1  setosa           4.9          3.0           1.4          0.2
# 2  setosa           4.7          3.2           1.3          0.2
# 3  setosa           4.6          3.1           1.5          0.2
# 4  setosa           5.0          3.6           1.4          0.2

# %% [markdown]
# #### Adam said to not do the dummy exercise

# %%
#copied from Nikki's since I dont know whatultratransofrmed dataframe mean
def prep_iris(df):
    df = df.drop(columns= (['species_id', 'measurement_id']))
    df = df.rename(columns = {'species_name': 'species'})
    return df

# %%
#New 'prep_iris function
prepped_iris = prep_iris(new_iris_data())
#take a look
prepped_iris.head()

#Why is measurement_id not found in axis affect this function?
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[149], line 2
#       1 #New 'prep_iris function
# ----> 2 prepped_iris = prep_iris(new_iris_data())
#       3 #take a look
#       4 prepped_iris.head()
#
# Cell In[148], line 3, in prep_iris(df)
#       2 def prep_iris(df):
# ----> 3     df = df.drop(columns= (['species_id', 'measurement_id']))
#       4     df = df.rename(columns = {'species_name': 'species'})
#       5     return df
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# ...

# %% [markdown]
# ## Using the Titanic dataset
#
# Use the function defined in acquire.py to load the Titanic data.
# Drop any unnecessary, unhelpful, or duplicated columns.
# Encode the categorical columns. Create dummy variables of the categorical columns and concatenate them onto the dataframe.
# Create a function named prep_titanic that accepts the raw titanic data, and returns the data with the transformations above applied.

# %%
# Get titanic data from codeup db
def new_titanic_data():
    # Create SQL query.
    sql_query = 'SELECT * FROM passengers'
    # Read in dataframe from Codeup db
    df = pd.read_sql(sql_query, get_connection('titanic_db'))
    return df


def get_titanic_data():
    if os.path.isfile('titanic_df.csv'):
        # If csv file exists, read in data from csv file.
        df = pd.read_csv('titanic_df.csv', index_col=0)  
    else:  
        # Read data from db into a dataframe
        df = new_titanic_data() 
        # Write dataframe to a csv file
        df.to_csv('titanic_df.csv')
    return df

# %%
titanic = new_titanic_data()
titanic.head()
# Out:
#    passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
#
#   embarked  class  deck  embark_town  alone
# 0        S  Third  None  Southampton      0
# 1        C  First     C    Cherbourg      0
# 2        S  Third  None  Southampton      1
# 3        S  First     C  Southampton      0
# 4        S  Third  None  Southampton      1

# %%
#drop redundant and unhelpful columns
new_titanic = titanic.drop(columns = ['age','class', 'embarked', 'passenger_id', 'deck'])
new_titanic.head()
# Out:
#    survived  pclass     sex  sibsp  parch     fare  embark_town  alone
# 0         0       3    male      1      0   7.2500  Southampton      0
# 1         1       1  female      1      0  71.2833    Cherbourg      0
# 2         1       3  female      0      0   7.9250  Southampton      1
# 3         1       1  female      1      0  53.1000  Southampton      0
# 4         0       3    male      0      0   8.0500  Southampton      1

# %%
#check for nulls 
new_titanic.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# sibsp          0
# parch          0
# fare           0
# embark_town    2
# alone          0
# dtype: int64

# %%
# drop all nulls from data frame
new_titanic.dropna().head()
# Out:
#    survived  pclass     sex  sibsp  parch     fare  embark_town  alone
# 0         0       3    male      1      0   7.2500  Southampton      0
# 1         1       1  female      1      0  71.2833    Cherbourg      0
# 2         1       3  female      0      0   7.9250  Southampton      1
# 3         1       1  female      1      0  53.1000  Southampton      0
# 4         0       3    male      0      0   8.0500  Southampton      1

# %% [markdown]
# #### Create new prep_titanic that acceptraw data and return with transformation

# %%
def prep_titanic(titanic):
    titanic = titanic.drop(columns=['class', 'embarked', 'passenger_id', 'deck', 'age'])
    titanic = titanic.dropna()
    return titanic

# %%
# take a look
prepped_titanic = prep_titanic(new_titanic_data())
prepped_titanic.head()
# Out:
#    survived  pclass     sex  sibsp  parch     fare  embark_town  alone
# 0         0       3    male      1      0   7.2500  Southampton      0
# 1         1       1  female      1      0  71.2833    Cherbourg      0
# 2         1       3  female      0      0   7.9250  Southampton      1
# 3         1       1  female      1      0  53.1000  Southampton      0
# 4         0       3    male      0      0   8.0500  Southampton      1

# %% [markdown]
# # Using the Telco dataset
# Use the function defined in acquire.py to load the Telco data.
# Drop any unnecessary, unhelpful, or duplicated columns. This could mean dropping foreign key columns but keeping the corresponding string values, for example.
# Encode the categorical columns. Create dummy variables of the categorical columns and concatenate them onto the dataframe.
# Create a function named prep_telco that accepts the raw telco data, and returns the data with the transformations above applied.

# %%
def new_telco_data():
    sql_query = ("SELECT * from customers JOIN contract_types USING (contract_type_id) JOIN internet_service_types USING (internet_service_type_id) JOIN payment_types USING (payment_type_id)")
    # Read in dataframe from Codeup db
    df = pd.read_sql(sql_query, get_connection('telco_churn'))
    return df


def get_telco_data():
    if os.path.isfile('telco.csv'):
        # If csv file exists read in data from csv file.
        df = pd.read_csv('telco.csv', index_col=0)
    else:
        # Read fresh data from db into a dataframe
        df = new_telco_data()
        # Cache data
        df.to_csv('telco.csv')
    return df

# %%
telco = new_telco_data()
telco.head()
# Out:
#    payment_type_id  internet_service_type_id  contract_type_id customer_id  \
# 0                2                         1                 2  0002-ORFBO
# 1                2                         1                 1  0003-MKNFE
# 2                1                         2                 1  0004-TLHLJ
# 3                1                         2                 1  0011-IGKFF
# 4                2                         2                 1  0013-EXCHZ
#
#    gender  senior_citizen partner dependents  tenure phone_service  ...  \
# 0  Female               0     Yes        Yes       9           Yes  ...
# 1    Male               0      No         No       9           Yes  ...
# 2    Male               0      No         No       4           Yes  ...
# 3    Male               1     Yes         No      13           Yes  ...
# 4  Female               1     Yes         No       3           Yes  ...
#
#   tech_support streaming_tv streaming_movies paperless_billing  \
# ...

# %%
new_telco = telco.drop(columns=['payment_type_id', 'internet_service_type_id', 'contract_type_id'])
new_telco.head()
# Out:
#   customer_id  gender  senior_citizen partner dependents  tenure  \
# 0  0002-ORFBO  Female               0     Yes        Yes       9
# 1  0003-MKNFE    Male               0      No         No       9
# 2  0004-TLHLJ    Male               0      No         No       4
# 3  0011-IGKFF    Male               1     Yes         No      13
# 4  0013-EXCHZ  Female               1     Yes         No       3
#
#   phone_service multiple_lines online_security online_backup  ...  \
# 0           Yes             No              No           Yes  ...
# 1           Yes            Yes              No            No  ...
# 2           Yes             No              No            No  ...
# 3           Yes             No              No           Yes  ...
# 4           Yes             No              No            No  ...
#
#   tech_support streaming_tv streaming_movies paperless_billing  \
# 0          Yes          Yes               No               Yes
# ...

# %%
def prep_telco(telco):
    telco = telco.drop(columns=['payment_type_id', 'internet_service_type_id', 'contract_type_id'])
    return telco

# %%
prepped_telco = prep_telco(new_telco_data())
prepped_telco.head()
# Out:
#   customer_id  gender  senior_citizen partner dependents  tenure  \
# 0  0002-ORFBO  Female               0     Yes        Yes       9
# 1  0003-MKNFE    Male               0      No         No       9
# 2  0004-TLHLJ    Male               0      No         No       4
# 3  0011-IGKFF    Male               1     Yes         No      13
# 4  0013-EXCHZ  Female               1     Yes         No       3
#
#   phone_service multiple_lines online_security online_backup  ...  \
# 0           Yes             No              No           Yes  ...
# 1           Yes            Yes              No            No  ...
# 2           Yes             No              No            No  ...
# 3           Yes             No              No           Yes  ...
# 4           Yes             No              No            No  ...
#
#   tech_support streaming_tv streaming_movies paperless_billing  \
# 0          Yes          Yes               No               Yes
# ...

# %% [markdown]
# # Split your data
#
# Write a function to split your data into train, test and validate datasets. Add this function to prepare.py.
# Run the function in your notebook on the Iris dataset, returning 3 datasets, train_iris, validate_iris and test_iris.
# Run the function on the Titanic dataset, returning 3 datasets, train_titanic, validate_titanic and test_titanic.
# Run the function on the Telco dataset, returning 3 datasets, train_telco, validate_telco and test_telco.

# %%
from sklearn.model_selection import train_test_split

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[177], line 3
#       1 seed = 42
# ----> 3 train, val_test = train_test_split(iris_df, train_size = 0.7,
#       4                                   random_state = seed,
#       5                                   stratify = iris_df.species)
#       6 val, test = train_test_split(val_test, train_size = 0.5,
#       7                             random_state = seed,
#       8                             stratify = val_test.species)
#       9 train.species.value_counts(normalize = True)
#
# NameError: name 'iris_df' is not defined
