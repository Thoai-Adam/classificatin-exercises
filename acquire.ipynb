# %%
# %autosave 0
# Out:
# Autosave disabled

# %%
import numpy as np
import pandas as pd
from pydataset import data
from env import get_connection
from sqlalchemy import create_engine, text

# %%
def new_titanic_data():
    sql_query = 'SELECT * FROM passengers'
df = pd.read_sql(sql_query, getconnection('titanic_db'))
return df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 def new_titanic_data():
#       2     sql_query = 'SELECT * FROM passengers'
# ----> 3 df = pd.read_sql(sql_query, getconnection('titanic_db'))
#       4 return df
#
# NameError: name 'sql_query' is not defined

# %%
def get_db_url(database):
    return get_connection(database)
url = get_db_url('telco_churn')
query = text('SELECT * FROM customers')
engine = create_engine(url)

employees_db = pd.read_sql(query, engine.connect())
employees_db
# Out:
#      customer_id  gender  senior_citizen partner dependents  tenure  \
# 0     0002-ORFBO  Female               0     Yes        Yes       9
# 1     0003-MKNFE    Male               0      No         No       9
# 2     0004-TLHLJ    Male               0      No         No       4
# 3     0011-IGKFF    Male               1     Yes         No      13
# 4     0013-EXCHZ  Female               1     Yes         No       3
# ...          ...     ...             ...     ...        ...     ...
# 7038  9987-LUTYD  Female               0      No         No      13
# 7039  9992-RRAMN    Male               0     Yes         No      22
# 7040  9992-UJOEL    Male               0      No         No       2
# 7041  9993-LHIEB    Male               0     Yes        Yes      67
# 7042  9995-HOTOH    Male               0     Yes        Yes      63
#
#      phone_service    multiple_lines  internet_service_type_id  \
# 0              Yes                No                         1
# 1              Yes               Yes                         1
# 2              Yes                No                         2
# 3              Yes                No                         2
# 4              Yes                No                         2
# ...            ...               ...                       ...
# 7038           Yes                No                         1
# 7039           Yes               Yes                         2
# 7040           Yes                No                         1
# 7041           Yes                No                         1
# 7042            No  No phone service                         1
#
#      online_security  ... device_protection tech_support streaming_tv  \
# 0                 No  ...                No          Yes          Yes
# 1                 No  ...                No           No           No
# 2                 No  ...               Yes           No           No
# 3                 No  ...               Yes           No          Yes
# 4                 No  ...                No          Yes          Yes
# ...              ...  ...               ...          ...          ...
# 7038             Yes  ...                No          Yes           No
# 7039              No  ...                No           No           No
# 7040              No  ...                No           No           No
# 7041             Yes  ...               Yes          Yes           No
# 7042             Yes  ...               Yes           No          Yes
#
#      streaming_movies contract_type_id  paperless_billing payment_type_id  \
# 0                  No                2                Yes               2
# 1                 Yes                1                 No               2
# 2                  No                1                Yes               1
# 3                 Yes                1                Yes               1
# 4                  No                1                Yes               2
# ...               ...              ...                ...             ...
# 7038               No                2                 No               2
# 7039              Yes                1                Yes               1
# 7040               No                1                Yes               2
# 7041              Yes                3                 No               2
# 7042              Yes                3                 No               1
#
#       monthly_charges  total_charges churn
# 0               65.60          593.3    No
# 1               59.90          542.4    No
# 2               73.90         280.85   Yes
# 3               98.00        1237.85   Yes
# 4               83.90          267.4   Yes
# ...               ...            ...   ...
# 7038            55.15          742.9    No
# 7039            85.10         1873.7   Yes
# 7040            50.30          92.75    No
# 7041            67.85        4627.65    No
# 7042            59.00         3707.6    No
#
# [7043 rows x 21 columns]
